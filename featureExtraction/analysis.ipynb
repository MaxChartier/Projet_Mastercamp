# %%
from analysis import *
import os

# %%
test_path = os.path.join(dataset_path, 'test', '00829_07.jpg')
display_img(test_path)

# %%
display_img(standardize_image(test_path))
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 display_img(None, standardize_image(test_path))
#
# File c:\Mastercamp-data\Projet_Mastercamp\featureExtraction\analysis.py:24, in standardize_image(img, shape)
#      23 def standardize_image(img, shape=(224, 224)):
# ---> 24     return cv2.resize(img, shape[::-1])
#
# error: OpenCV(4.11.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
