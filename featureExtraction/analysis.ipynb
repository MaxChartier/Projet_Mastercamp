# %%
from analysis import *
import os

# %%
test_path = os.path.join(dataset_path, 'test', '00829_07.jpg')
display_img(test_path)

# %%
file_size = get_file_size(test_path)
print(file_size)
# Out:
# {'bytes': 91789, 'ko': 89.64, 'mo': 0.0875}

# %%
file_dimensions = get_dimensions(test_path)
print(file_dimensions)
# Out:
# {'w': 600, 'h': 600, 'pixels_tt': 360000}

# %%
img = Image.open(test_path)
std_image = standardize_image(test_path)

# %%
get_avg_color(std_image)
# Out:
# {'avg_red': 113.93,
#  'avg_green': 117.75,
#  'avg_blue': 108.75,
#  'brightness': 113.48}

# %%
plot_color_histogram(std_image)
